# %%
from tkinter import *
from tkinter import ttk
import matplotlib
matplotlib.use("TkAgg")
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure

#import circuit as c
#import gates as gt

# %%
#defining game functions for the buttons

def initalise():
    
def play_gate1():
    gate = gateplay1.get()
    T_qubit = gateplay1.get(1)
    C_qubit = gateplay1.get(2)
    
    if gate in c.hand1:
        if gate == m:
            controller.show_frame("Mframe")
            
        elif gate == h:
            
        elif gate == x:
            
        elif gate == c:
            
        elif gate == s:
            
        else gate == t:
        
        
    else: gateplay1.print("not in hand")
    
def play_gate2():
    gate = gateplay2.get()
    T_qubit = gateplay2.get(1)
    C_qubit = gateplay2.get(2)
    
    if gate in c.hand2:
        if gate == m:
            controller.show_frame("Mframe")
            
        elif gate == h:
            
        elif gate == x:
            
        elif gate == c:
            
        elif gate == s:
            
        else gate == t:
        
        
        
    else: gateplay2.print("not in hand")

def play_gate3():
    gate = gateplay3.get(0)
    T_qubit = gateplay3.get(1)
    C_qubit = gateplay3.get(2)
    
    if gate in c.hand3:
        if gate == m:
            controller.show_frame("Mframe")
            
        elif gate == h:
            
        elif gate == x:
            
        elif gate == c:
            
        elif gate == s:
            
        else gate == t:
        
    else: gateplay3.print("not in hand")
# Out:
#   File "<ipython-input-91-fd1c1b4da9eb>", line 4
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
fig = Figure(figsize=(5,5), dpi=100)
a = fig.add_subplot(111)
a.plot([1,1,2,3,4,5,6],[22,3,4,5,6,7,8])

# %%
import tkinter as tk                # python 3
from tkinter import font as tkfont  # python 3


class QuantumPoker(tk.Tk):

    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)

        self.title_font = tkfont.Font(family='Helvetica', size=18, weight="bold", slant="italic")

        # the container is where we'll stack a bunch of frames
        # on top of each other, then the one we want visible
        # will be raised above the others
        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}
        for F in (HomePage, StartPage, PageOne, PageTwo, PageThree, Mframe):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame

            # put all of the pages in the same location;
            # the one on the top of the stacking order
            # will be the one that is visible.
            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame("HomePage")

    def show_frame(self, page_name):
        '''Show a frame for the given page name'''
        frame = self.frames[page_name]
        frame.tkraise()
        fig = fig #need to add c.fig
        
        
        

class HomePage(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="Quantum Poker", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        
        
        
        
        button1 = tk.Button(self, text="Play",
                            command=lambda: controller.show_frame("StartPage"))
        button1.pack()
        

        
        
        
class StartPage(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="Quantum Poker", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        
        button = tk.Button(self, text="Press to Initalise Cuircet and Start Game", command= initalise)

        button1 = tk.Button(self, text="Go to Player 1",
                            command=lambda: controller.show_frame("PageOne"))
        button2 = tk.Button(self, text="Go to Player 2",
                            command=lambda: controller.show_frame("PageTwo"))
        
        button3 = tk.Button(self, text="Go to Player 3",
                           command=lambda: controller.show_frame("PageThree"))
        
        canvas = FigureCanvasTkAgg(fig, self)
        #canvas.show()
        canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=True)
        
    
        button.pack()
        button1.pack()
        button2.pack()
        button3.pack()


        
        
        
        
        
class PageOne(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="Quantum Poker", font=controller.title_font)
        
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        canvas = FigureCanvasTkAgg(fig, self)
       # canvas.show()
        canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=True)
        
        hand1 = tk.Label(text="Hand =" f"{c.hand1}")#need to add c.hand1
        gateplay1 = tk.Entry(self,width=15)
        btn_gateplay = tk.Button(self, text = "Play Gate!", command=play_gate1)
        form_lbl = tk.Label(self, text="Enter play in form gate target control eg h01")
        
        
        
        label.pack(side="top", fill="x", pady=10)
        hand1.pack()
        button.pack()
        btn.gateplay
        form_lbl.pack()
        
        
        

    
    
    
    
    


class PageTwo(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="Quantum Poker Player 2 ", font=controller.title_font)
        
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        canvas = FigureCanvasTkAgg(fig, self)
        #canvas.show()
        canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=True)
       
        hand2 = tk.Label(text="Hand =" f"{c.hand2}")#need to add c.hand1
        gateplay2 = tk.Entry(self,width=15)
        btn_gateplay = tk.Button(self, text = "Play gate!", command=play_gate2)
        form_lbl = tk.Label(self, text="Enter play in form gate target control eg h01")
        
        
        
        label.pack(side="top", fill="x", pady=10)
        hand1.pack()
        button.pack()
        btn.gateplay
        form_lbl.pack()
        
        
        
        
        
        
        
        

class PageThree(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="Quantum Poker Player 3", font=controller.title_font)
        
        
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        canvas = FigureCanvasTkAgg(fig, self)
        #canvas.show()
        canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=True)
        
        
        hand3 = tk.Label(text="Hand =" f"{c.hand3}")#need to add c.hand1
        gateplay3 = tk.Entry(self,width=15)
        btn_gateplay = tk.Button(self, text = "Play gate!", command=play_gate3)
        form_lbl = tk.Label(self, text="Enter play in form gate target control eg h01")
        
        
        
        label.pack(side="top", fill="x", pady=10)
        hand1.pack()
        button.pack()
        btn.gateplay
        form_lbl.pack()
        
        
        
        
        
        
class Mframe(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="Quantum Poker results", font=controller.title_font)
        results = tk.Button(self,text="See results", command=c.run())
        canvas = FigureCanvasTkAgg(figfinal, self)
        #canvas.show()
        canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=True)
        
        
        button = tk.Button(self, text="Play again?",
                           command=lambda: controller.show_frame("StartPage"))
        
        button.pack()
        
        
        
        
        
        
if __name__ == "__main__":
    app = QuantumPoker()
    app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-18cdf9c76396> in <module>
#     171
#     172 if __name__ == "__main__":
# --> 173     app = QuantumPoker()
#     174     app.mainloop()
#
# <ipython-input-100-18cdf9c76396> in __init__(self, *args, **kwargs)
#      21         for F in (HomePage, StartPage, PageOne, PageTwo, PageThree):
#      22             page_name = F.__name__
# ---> 23             frame = F(parent=container, controller=self)
#      24             self.frames[page_name] = frame
#      25
#
# <ipython-input-100-18cdf9c76396> in __init__(self, parent, controller)
#     105         canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=True)
#     106
# --> 107         hand1 = tk.Label(text="Hand =" f"{c.hand1}")#need to add c.hand1
#     108         gateplay = tk.Entry(self,width=15)
# ...

# %% [markdown]
# print(name)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-c68807c6bf41> in <module>
#       2 frame = tk.Frame(master=window, width=150, height=150)
#       3 frame.pack()
# ----> 4 la
#
# NameError: name 'la' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-ee8800f09fc9> in <module>
#       6
#       7 while True:
# ----> 8     if events_list ==[]:
#       9         continue
#      10     event = events_list[0]
#
# KeyboardInterrupt:
